# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/Users/caseycloutier/Desktop/ECO688/Cleaned Data/data.csv')

# %%
counties=data.loc[(data['area_title'] == 'LOS ANGELES, CA')|(data['area_title'] == 'COOK, IL')|(data['area_title'] == 'HARRIS, IL')|(data['area_title'] == 'MARICOPA, AZ')|(data['area_title'] == 'SAN DIEGO, CA')]

# %%
# Out:
#        Unnamed: 0     area_title        date   emplvl  number_schools  \
# 13416       15072       COOK, IL  2020-01-01  2324574          1226.0
# 13417       15073       COOK, IL  2020-02-01  2327484          1230.0
# 13418       15074       COOK, IL  2020-03-01  2313057          1225.0
# 13419       15075       COOK, IL  2020-04-01  1997003          1209.0
# 13420       15076       COOK, IL  2020-05-01  1998602          1218.0
# ...           ...            ...         ...      ...             ...
# 52195       59803  SAN DIEGO, CA  2021-08-01  1229754           659.0
# 52196       59804  SAN DIEGO, CA  2021-09-01  1236134           663.0
# 52197       59805  SAN DIEGO, CA  2021-10-01  1261683           664.0
# 52198       59806  SAN DIEGO, CA  2021-11-01  1275396           651.0
# 52199       59807  SAN DIEGO, CA  2021-12-01  1275678           655.0
#
#        share_all_closed_50  share_all_closed_25  share_all_closed_75  \
# ...
